# %% [markdown]
# RESUMEN CODIGOS CLASE 1

# %%
print("Hola") #Muestra lo que esta ()
# Out:
# Hola

# %%
valor = input("Ingrese dato") #ingresar valores 
valor                         #se muestre valor
# Out:
# 'Dani'

# %%
type(5) #indentifica que valor dentro () , si numero, texto, lista, etc
# Out:
# int

# %% [markdown]
# SALIDA DE INFORMACION

# %%
suma = 5
# Opcion 1
print("El valor de la suma es "+  str(suma)) # str(suma) 

# Opcion 2 -> Mejor opcion
print(f"El valor de la suma es: {suma}") # formatea el numero a texto

# opcion 3 -> Otra buena Opcion
print("El valor de la suma es: {}".format(suma))
# Out:
# El valor de la suma es 5
# El valor de la suma es: 5
# El valor de la suma es: 5

# %% [markdown]
# Texto entre COMILLAS
# -Simple -> 'Esta es una cadena de texto'
# -Doble -> "Esta' es otra cadena de texto"
# - Triple -> se usa cuando el texto no se haya en una sola linea
#
# msg = """
# Esta cadena\ttiene más de una línea
# por lo que se usa
# 3 comillas dobles
# dasdas
# """
# # \n -> representa salto de linea
# # \t -> representa tab o espacio

# %%
#Concatenar texto
print("Un divertido "+"programa "+"de "+ "radio")
cad1 = "Un divertido "
cad2 = "programa"

print(cad1 + cad2)

area=input("Di tu nombre")
print("Tu nombre es\t:",area)
# Out:
# Un divertido programa de radio
# Un divertido programa
# Tu nombre es	: Dani

# %%
## Multiplicar una cadena 
print('Hola')
print('Hola'*3)
# Out:
# Hola
# HolaHolaHola

# %%
## Conocer largo de una cadena, cuenta espacios
len('H     ola') # cadena de 4 caracteres
# Out:
# 9

# %%
## Convirtiendo a string
str(59)
# Out:
# '59'

# %% [markdown]
# DATOS NUMERICOS
#
# ENTEROS -> int
# DECIMALES -> float
#
# OPERACIONES NUMERICAS
# ![image.png](attachment:image.png)

# %% [markdown]
# *Modulo es el residuo de la division

# %%
##convierte otro tipo de dato a entero decimal o texto
int(3.55)
int('3')
# Out:
# 3

# %%
# Convierto "int" o "sting" a float
float(3)
float('3.245')
# Out:
# 3.0

# %%
import math
radio = 2
area = math.pow(radio,2) #exponente a la 2
print (area)
# Out:
# 4.0

# %% [markdown]
# DATOS BOOLEANOS
#
# Definir valor VERDADERO o FALSO
#
# OPERADORES RELACIONALES
#
# ![image.png](attachment:image.png)
#
# OPERADORES LOGISTICOS
#
# ![image-2.png](attachment:image-2.png)

# %%
# cualquier número excepto el 0 se interpreta como verdadero
bool(20)
# Out:
# True

# %%
bool(0)
# Out:
# False

# %% [markdown]
# ADICIONALES

# %%
# Aumento dos a la variable a (a = a+2)
a=2
a += 2
print(a)
# Out:
# 4

# %%
# a = a * 10
a *= 10
a
# Out:
# 40

# %%
a /= 5
a
# Out:
# 8.0

# %% [markdown]
# 2. Entrada de datos por Argumentos
#
# Para poder enviar información a un script y manejarla, tenemos que utilizar la librería de sistema sys. En ella encontraremos la lista argv que almacena los argumentos enviados al script.

# %%
# Hacer en vscode
import sys
print(sys.argv)
# Out:
# ['/home/vscode/.local/lib/python3.9/site-packages/ipykernel_launcher.py', '--f=/home/vscode/.local/share/jupyter/runtime/kernel-v2-76341jCc5luFO5Jvt.json']

# %% [markdown]
# FUNCIONES CONDICIONALES

# %%
# Sentencia if (si) -> se activa cuando el valor de mi condicional es True

# if condition:
#     # 4 carecteres de identacion
#     pass ///*Opcional, NO SE HACE NADA SI NO SE CUMPLE LA CONDICION

password = '1234'

if password=='1234':
    print('Bienvenido!!')
# Out:
# Bienvenido!!

# %%
# Sentencia else (si no) -> sentencias 'else' se activan si condicional es False
x = 85
if x == 8 :
    # 4 espacios
    print('el valor de x es 8')
else:
    print('el valor de x = {} es distinto de 8'.format(x))
# Out:
# el valor de x = 85 es distinto de 8

# %%
# Sentencia else (si no)
x=50
if x==8 :
    print('el valor de x es 8')
elif x==9:
    print('el valor de x es 9')
elif x==10:
    print('el valor de x es 10')
else:
    # si nada de lo anterior se cumple, se ejecuta else
    print('el valor de x es distinto de 8,9 y 10')
# Out:
# el valor de x es distinto de 8,9 y 10

# %%
# Sentencia if anidado -> implica crear un if dentro de otro if

"""Ejercicio
Escribe un programa en Python que solicite al usuario ingresar un número entero 
y luego verifique si es positivo y par. Muestra un mensaje correspondiente en cada caso.

"""

numero_entero = int(input('Ingrese un número entero: '))

if numero_entero>0:
    print('EL numero ingresado es positivo')

    if numero_entero %2 == 0:
        print('El numero ingresado es par')
# Out:
# EL numero ingresado es positivo
# El numero ingresado es par

# %% [markdown]
# COLECCION DE DATOS
